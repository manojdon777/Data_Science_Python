# %% [markdown]
# #   <font color = darkblue size =6.5><center> Word2Vec

# %% [markdown]
# ## Pretrained Vectors

# %% [markdown]
# word2vec  - google model
#           - word2vec on our own dataset

# %%
from gensim.models import KeyedVectors
fileame = r'C:\Users\DELL\Documents\NLP\GoogleNews-vectors-negative300.bin'
model = KeyedVectors.load_word2vec_format(fileame,binary=True)

# %%
(model['yahoo'])
# Out:
# array([ 0.13183594, -0.05419922, -0.08886719,  0.10742188, -0.19238281,
#        -0.03808594, -0.03063965,  0.05639648,  0.14160156,  0.02624512,
#        -0.16601562, -0.47265625, -0.12792969, -0.01287842,  0.01708984,
#         0.16308594, -0.02832031,  0.203125  ,  0.01184082, -0.140625  ,
#        -0.00976562,  0.07470703,  0.09228516, -0.16503906, -0.35742188,
#        -0.10400391, -0.37304688,  0.40234375,  0.06982422, -0.09570312,
#         0.04956055,  0.19335938, -0.23535156,  0.11474609, -0.11376953,
#         0.00927734,  0.22363281,  0.25976562,  0.21582031,  0.11035156,
#         0.11279297, -0.08642578,  0.31054688,  0.23144531,  0.02856445,
#         0.05957031, -0.09179688, -0.07568359, -0.08447266, -0.12890625,
#        -0.11230469,  0.12353516, -0.01696777,  0.22265625,  0.00970459,
#        -0.03173828, -0.25      ,  0.09375   ,  0.11914062, -0.18261719,
#         0.03613281, -0.1484375 , -0.15039062,  0.03857422, -0.19238281,
# ...

# %%
# cosine  similarity 

king(A) = 3i+4j+5k queen(B) = 3i+4j-5k

cosine_similarity =( A. B)/ |A|*|B|   = -1 to +1   -1 : two words are not similar at all
                                                   +1  : similar words

# %%
model.similarity('king','queen')
# Out:
# 0.6510957

# %%
model.most_similar('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]

# %%
model.doesnt_match(['java','python','monkey','html','sql'])
# Out:
# 'monkey'

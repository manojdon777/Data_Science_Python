# %%
import pandas as pd
df = pd.read_csv('Emp_Records2.csv')

# %%
df.head(10)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36           60.0           13.68  168251.0
# 1  940761     Brenda       47.02           60.0            9.01   51063.0
# 2  428945        Joe       54.15            NaN            0.98   50155.0
# 3  408351      Diane         NaN           51.0             NaN  180294.0
# 4  193819   Benjamin       40.31            NaN             NaN  117642.0
# 5  499687    Patrick         NaN           58.0             NaN   72305.0
# 6  539712      Nancy       22.14           50.0            0.87   98189.0
# 7  380086      Carol         NaN            NaN             NaN       NaN
# 8  477616    Frances       58.18           42.0           23.27  121587.0
# 9  162402      Diana       29.73           60.0            3.44   43010.0
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# 8         Delmita
# 9  Eureka Springs

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False           True           False   False
# 3    False       False        True          False            True   False
# 4    False       False       False           True            True   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 95  False
# 96  False
# 97  False
# 98  False
# 99  False
#
# [100 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        3
# Weight in Kgs     3
# Age in Company    4
# Salary            1
# City              0
# dtype: int64

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False          False           False   False
# 1    False       False       False          False           False   False
# 2    False       False       False           True           False   False
# 3    False       False        True          False            True   False
# 4    False       False       False           True            True   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 95  False
# 96  False
# 97  False
# 98  False
# 99  False
#
# [100 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        3
# Weight in Kgs     3
# Age in Company    4
# Salary            1
# City              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      97 non-null     float64
#  3   Weight in Kgs   97 non-null     float64
#  4   Age in Company  96 non-null     float64
#  5   Salary          99 non-null     float64
#  6   City            100 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.6+ KB

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15            NaN            0.98   50155.0
# 3   408351      Diane         NaN           51.0             NaN  180294.0
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df['Age in Yrs'] = df['Age in Yrs'].fillna(df['Age in Yrs'].mean())
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois   36.360000           60.0           13.68  168251.0
# 1   940761     Brenda   47.020000           60.0            9.01   51063.0
# 2   428945        Joe   54.150000            NaN            0.98   50155.0
# 3   408351      Diane   39.074433           51.0             NaN  180294.0
# 4   193819   Benjamin   40.310000            NaN             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose   22.820000           89.0            1.05  129774.0
# 96  704709     Harold   32.610000           77.0            5.93  156194.0
# 97  461593     Nicole   52.660000           60.0           28.53   95673.0
# 98  392491    Theresa   29.600000           57.0            6.99   51015.0
# 99  495141      Tammy   38.380000           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df['Age in Yrs'].mean()
# Out:
# 39.074432989690735

# %%
df['Weight in Kgs'].mean()
# Out:
# 58.16494845360825

# %%
df['Weight in Kgs'] = df['Weight in Kgs'].fillna(df['Weight in Kgs'].mean())
df.head(10)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0  677509       Lois       36.36      60.000000           13.68  168251.0
# 1  940761     Brenda       47.02      60.000000            9.01   51063.0
# 2  428945        Joe       54.15      58.164948            0.98   50155.0
# 3  408351      Diane         NaN      51.000000             NaN  180294.0
# 4  193819   Benjamin       40.31      58.164948             NaN  117642.0
# 5  499687    Patrick         NaN      58.000000             NaN   72305.0
# 6  539712      Nancy       22.14      50.000000            0.87   98189.0
# 7  380086      Carol         NaN      58.164948             NaN       NaN
# 8  477616    Frances       58.18      42.000000           23.27  121587.0
# 9  162402      Diana       29.73      60.000000            3.44   43010.0
#
#              City
# 0          Denver
# 1       Stonewall
# 2    Michigantown
# 3        Hydetown
# 4         Fremont
# 5       Macksburg
# 6         Atlanta
# 7     Blanchester
# 8         Delmita
# 9  Eureka Springs

# %%
df.dropna(thresh=6).head(10)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15            NaN            0.98   50155.0
# 6   539712      Nancy       22.14           50.0            0.87   98189.0
# 8   477616    Frances       58.18           42.0           23.27  121587.0
# 9   162402      Diana       29.73           60.0            3.44   43010.0
# 10  231469      Ralph       42.50           80.0            8.29  118457.0
# 11  153989       Jack       22.21           61.0            0.56   82965.0
# 12  386158    Melissa       45.45           55.0            1.68  166892.0
# 13  301576      Wayne       21.10           87.0            0.02   92758.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 6          Atlanta
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas
# 12   New Matamoras
# 13           Maida

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        3
# Weight in Kgs     0
# Age in Company    4
# Salary            1
# City              0
# dtype: int64

# %%
df.dropna(thresh=10,axis=1)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36      60.000000           13.68  168251.0
# 1   940761     Brenda       47.02      60.000000            9.01   51063.0
# 2   428945        Joe       54.15      58.164948            0.98   50155.0
# 3   408351      Diane         NaN      51.000000             NaN  180294.0
# 4   193819   Benjamin       40.31      58.164948             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82      89.000000            1.05  129774.0
# 96  704709     Harold       32.61      77.000000            5.93  156194.0
# 97  461593     Nicole       52.66      60.000000           28.53   95673.0
# 98  392491    Theresa       29.60      57.000000            6.99   51015.0
# 99  495141      Tammy       38.38      55.000000            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df.head(30)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36      60.000000           13.68  168251.0
# 1   940761     Brenda       47.02      60.000000            9.01   51063.0
# 2   428945        Joe       54.15      58.164948            0.98   50155.0
# 3   408351      Diane         NaN      51.000000             NaN  180294.0
# 4   193819   Benjamin       40.31      58.164948             NaN  117642.0
# 5   499687    Patrick         NaN      58.000000             NaN   72305.0
# 6   539712      Nancy       22.14      50.000000            0.87   98189.0
# 7   380086      Carol         NaN      58.164948             NaN       NaN
# 8   477616    Frances       58.18      42.000000           23.27  121587.0
# 9   162402      Diana       29.73      60.000000            3.44   43010.0
# 10  231469      Ralph       42.50      80.000000            8.29  118457.0
# 11  153989       Jack       22.21      61.000000            0.56   82965.0
# 12  386158    Melissa       45.45      55.000000            1.68  166892.0
# 13  301576      Wayne       21.10      87.000000            0.02   92758.0
# 14  441771     Cheryl       59.47      47.000000           26.69   92220.0
# 15  528509      Paula       50.97      42.000000           22.95  152654.0
# 16  912990     Joshua       47.23      68.000000           14.91  184896.0
# 17  214352    Theresa       24.66      59.000000            2.52  197537.0
# 18  890290      Julia       58.08      56.000000           12.43  141518.0
# 19  622406     Thomas       49.85      73.000000           19.15   73862.0
# 20  979607      Carol       22.64      56.000000            1.26   93967.0
# 21  969580    Matthew       23.77      56.000000            1.47   52237.0
# 22  426038       Joan       44.72      56.000000            7.58  111673.0
# 23  388642       Ruby       37.27      59.000000            3.91  160623.0
# 24  560455    Carolyn       59.42      53.000000           16.08   42005.0
# 25  477253       Anne       28.02      60.000000            3.68  103160.0
# 26  263480     Daniel       27.59      60.000000            3.40  153790.0
# 27  683826      Roger       48.09      77.000000            8.50  129625.0
# 28  474599      Maria       42.39      41.000000           18.84   48944.0
# 29  335732     Brenda       53.68      41.000000           29.96   60508.0
#
#               City
# 0           Denver
# 1        Stonewall
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha
# 11       Las Vegas
# 12   New Matamoras
# 13           Maida
# 14        Quecreek
# 15      Beulaville
# 16     New Douglas
# 17     Toeterville
# 18   Primm Springs
# 19       Dutchtown
# 20      Shreveport
# 21     Heathsville
# 22      Middleport
# 23        Woodbury
# 24     Saint Cloud
# 25       Stockholm
# 26         Manning
# 27    Mount Vernon
# 28    Lawrenceburg
# 29            Mesa

# %%
df = pd.read_csv('Emp_Records2.csv')
df1 = df.copy()
df1
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15            NaN            0.98   50155.0
# 3   408351      Diane         NaN           51.0             NaN  180294.0
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df['Emp ID'].nunique()
# Out:
# 100

# %%
df.head(100)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15            NaN            0.98   50155.0
# 3   408351      Diane         NaN           51.0             NaN  180294.0
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma
#
# [100 rows x 7 columns]

# %%
df.replace({'Detroit':'Mumbai','Alma':'Pune'},inplace = True)
df.head(100)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company    Salary  \
# 0   677509       Lois       36.36           60.0           13.68  168251.0
# 1   940761     Brenda       47.02           60.0            9.01   51063.0
# 2   428945        Joe       54.15            NaN            0.98   50155.0
# 3   408351      Diane         NaN           51.0             NaN  180294.0
# 4   193819   Benjamin       40.31            NaN             NaN  117642.0
# ..     ...        ...         ...            ...             ...       ...
# 95  639892       Jose       22.82           89.0            1.05  129774.0
# 96  704709     Harold       32.61           77.0            5.93  156194.0
# 97  461593     Nicole       52.66           60.0           28.53   95673.0
# 98  392491    Theresa       29.60           57.0            6.99   51015.0
# 99  495141      Tammy       38.38           55.0            2.26   93650.0
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ..           ...
# 95        Biloxi
# 96  Carol Stream
# 97        Mumbai
# 98      Mc Grath
# 99          Pune
#
# [100 rows x 7 columns]

# %%
df.filter(regex = 'Age|Sal')
# Out:
#     Age in Yrs  Age in Company    Salary
# 0        36.36           13.68  168251.0
# 1        47.02            9.01   51063.0
# 2        54.15            0.98   50155.0
# 3          NaN             NaN  180294.0
# 4        40.31             NaN  117642.0
# ..         ...             ...       ...
# 95       22.82            1.05  129774.0
# 96       32.61            5.93  156194.0
# 97       52.66           28.53   95673.0
# 98       29.60            6.99   51015.0
# 99       38.38            2.26   93650.0
#
# [100 rows x 3 columns]

# %%
df1['Age in Yrs'].quantile(1.0)
# Out:
# 59.47
